# %%
import numpy as np
import pandas as pd
import mdptoolbox.mdp as mdp

# %%
car_df = pd.read_csv("../In-Class/howard_autoReplacement_data.csv")

# %%
car_df
# Out:
#      i     C     T    E      p
# 0    0  2000  1600   50  1.000
# 1    1  1840  1460   53  0.999
# 2    2  1680  1340   56  0.998
# 3    3  1560  1230   59  0.997
# 4    4  1300  1050   62  0.996
# 5    5  1220   980   65  0.994
# 6    6  1150   910   68  0.991
# 7    7  1080   840   71  0.988
# 8    8   900   710   75  0.985
# 9    9   840   650   78  0.983
# 10  10   780   600   81  0.980
# 11  11   730   550   84  0.975
# 12  12   600   480   87  0.970
# 13  13   560   430   90  0.965
# 14  14   520   390   93  0.960
# 15  15   480   360   96  0.955
# 16  16   440   330  100  0.950
# 17  17   420   310  103  0.945
# 18  18   400   290  106  0.940
# 19  19   380   270  109  0.935
# 20  20   360   255  112  0.930
# 21  21   345   240  115  0.925
# 22  22   330   225  118  0.919
# 23  23   315   210  121  0.910
# 24  24   300   200  125  0.900
# 25  25   290   190  129  0.890
# 26  26   280   180  133  0.880
# 27  27   265   170  137  0.865
# 28  28   250   160  141  0.850
# ...
