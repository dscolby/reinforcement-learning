# %% [markdown]
# Darren Colby
#
# MSCA 32020
#
# Homework 1
#
# The first cell uses jupyter magic to make it so we do not need to restart the kernel after changing code and imports functions from segment_driver to run episodes.

# %%
# %load_ext autoreload
# %autoreload 2

import segment_driver as driver

# %% [markdown]
# ## Mobile robot
#
# Consider the mobile robot problem described in section 2.5 in the “Introduction” lecture. Note that the results will differ from those in the lecture since the data is simulated.
#
# 1) Under the “always try to go right” policy:
#
# - Rerun the code and recreate table 2.1, 2.4, and 2.6
# - Recreate figures 2.2 and 2.3
# - Construct the transition probability matrix

# %%
# Table 2.1
driver.run_episode()
# Out:
#      t  observation  observation_next  action  reward  beta    beta^t  \
# 0    0            0                 1     1.0   -0.05  0.98  1.000000
# 1    1            1                 2     1.0   -0.05  0.98  0.980000
# 2    2            2                 3     1.0   -0.05  0.98  0.960400
# 3    3            3                 2     1.0   -0.05  0.98  0.941192
# 4    4            2                 3     1.0   -0.05  0.98  0.922368
# 5    5            3                 4     1.0   -0.05  0.98  0.903921
# 6    6            4                 5     1.0   -0.05  0.98  0.885842
# 7    7            5                 6     1.0   -0.05  0.98  0.868126
# 8    8            6                 5     1.0   -0.05  0.98  0.850763
# 9    9            5                 6     1.0   -0.05  0.98  0.833748
# 10  10            6                 7     1.0   -0.05  0.98  0.817073
# 11  11            7                 8     1.0   -0.05  0.98  0.800731
# ...

# %%
# Table 2.4
right_episodes = driver.run_episodes()
driver.tab_2_4(right_episodes)
# Out:
#        beta^t_reward
# count    1000.000000
# mean        0.009474
# std         0.017388
# min        -0.023125
# 1%         -0.019656
# 5%         -0.014918
# 10%        -0.012533
# 25%        -0.005784
# 50%         0.005312
# 75%         0.025213
# 90%         0.041812
# 95%         0.041812
# 99%         0.041812
# max         0.041812

# %%
# Table 2.6
right_value_functions = driver.estimate_v()
right_policy_summary = driver.summarize(right_value_functions)
right_policy_summary
# Out:
#     initial_state  count      mean       std       min    1%     5%      10%  \
# 0              -9   1000 -0.028284  0.141049 -1.000000 -0.05 -0.049 -0.04802
# 1              -8   1000 -0.019834  0.118537 -0.980000 -0.05 -0.049 -0.04802
# 2              -7   1000 -0.016920  0.116825 -0.960400 -0.05 -0.049 -0.04802
# 3              -6   1000 -0.015485  0.121820 -0.941192 -0.05 -0.049 -0.04802
# 4              -5   1000 -0.013042  0.131300 -0.922368 -0.05 -0.049 -0.04802
# 5              -4   1000 -0.010658  0.140056 -0.050000 -0.05 -0.049 -0.04802
# 6              -3   1000 -0.008083  0.149313 -0.050000 -0.05 -0.049 -0.04802
# 7              -2   1000 -0.005114  0.159064 -0.050000 -0.05 -0.049 -0.04802
# 8              -1   1000 -0.001400  0.170407 -0.050000 -0.05 -0.050 -0.04900
# 9               0   1000  0.003031  0.182812 -0.050000 -0.05 -0.050 -0.04900
# 10              1   1000  0.009886  0.200215 -0.050000 -0.05 -0.050 -0.04900
# ...

# %%
# Figures 2.2 and 2.3
driver.plot_fig_2_2(right_value_functions) | driver.plot_fig_2_3(right_value_functions)
# Out:
# alt.HConcatChart(...)

# %%
# Transition matrix
driver.transition_matrix(right_value_functions)
# Out:
# <style type="text/css">
# #T_21d5e_row0_col0, #T_21d5e_row0_col2, #T_21d5e_row1_col1, #T_21d5e_row1_col3, #T_21d5e_row2_col4, #T_21d5e_row3_col5, #T_21d5e_row4_col6, #T_21d5e_row5_col7, #T_21d5e_row6_col8, #T_21d5e_row7_col9, #T_21d5e_row8_col10, #T_21d5e_row9_col11, #T_21d5e_row10_col12, #T_21d5e_row11_col13, #T_21d5e_row12_col14, #T_21d5e_row13_col15, #T_21d5e_row14_col16, #T_21d5e_row15_col17, #T_21d5e_row16_col18, #T_21d5e_row17_col19, #T_21d5e_row18_col20 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# 2) Under the “always try to go left” policy:
#
# - Rerun the code and recreate table 2.1, 2.4, and 2.6
# - Recreate figures 2.2 and 2.3
# - Construct the transition probability matrix

# %%
# Table 2.1
driver.run_episode(direction="left")
# Out:
#    t  observation  observation_next  action  reward  beta    beta^t  \
# 0  0            0                -1     0.0   -0.05  0.98  1.000000
# 1  1           -1                -2     0.0   -0.05  0.98  0.980000
# 2  2           -2                -3     0.0   -0.05  0.98  0.960400
# 3  3           -3                -4     0.0   -0.05  0.98  0.941192
# 4  4           -4                -5     0.0   -0.05  0.98  0.922368
# 5  5           -5                -6     0.0   -0.05  0.98  0.903921
# 6  6           -6                -7     0.0   -0.05  0.98  0.885842
# 7  7           -7                -8     0.0   -0.05  0.98  0.868126
# 8  8           -8                -9     0.0   -0.05  0.98  0.850763
# 9  9           -9               -10     0.0   -1.00  0.98  0.833748
#
#    beta^t_reward
# 0      -0.050000
# 1      -0.049000
# 2      -0.048020
# 3      -0.047060
# 4      -0.046118
# 5      -0.045196
# 6      -0.044292
# 7      -0.043406
# 8      -0.042538
# 9      -0.833748

# %%
# Table 2.4
left_episodes = driver.run_episodes(direction="left")
driver.tab_2_4(left_episodes)
# Out:
#        beta^t_reward
# count    1000.000000
# mean       -0.090236
# std         0.019784
# min        -0.124938
# 1%         -0.124938
# 5%         -0.124938
# 10%        -0.124938
# 25%        -0.108242
# 50%        -0.087009
# 75%        -0.073908
# 90%        -0.064895
# 95%        -0.058237
# 99%        -0.050879
# max        -0.041211

# %%
# Table 2.6
left_value_functions = driver.estimate_v(direction="left")
left_policy_summary = driver.summarize(left_value_functions)
left_policy_summary
# Out:
#     initial_state  count      mean       std       min        1%        5%  \
# 0              -9   1000 -0.611103  0.460832 -1.000000 -1.000000 -1.000000
# 1              -8   1000 -0.319036  0.416071 -0.980000 -0.980000 -0.980000
# 2              -7   1000 -0.220303  0.349404 -0.960400 -0.960400 -0.960400
# 3              -6   1000 -0.176734  0.306259 -0.941192 -0.941192 -0.941192
# 4              -5   1000 -0.141585  0.263331 -0.922368 -0.922368 -0.885842
# 5              -4   1000 -0.124345  0.238163 -0.903921 -0.903921 -0.833748
# 6              -3   1000 -0.110605  0.215598 -0.885842 -0.885842 -0.817073
# 7              -2   1000 -0.099410  0.195675 -0.868126 -0.868126 -0.769022
# 8              -1   1000 -0.091453  0.180198 -0.850763 -0.817073 -0.723798
# 9               0   1000 -0.084374  0.165565 -0.833748 -0.800731 -0.681233
# 10              1   1000 -0.078106  0.152122 -0.817073 -0.784717 -0.591395
# ...

# %%
# Figures 2.2 and 2.3
driver.plot_fig_2_2(left_value_functions) | driver.plot_fig_2_3(left_value_functions)
# Out:
# alt.HConcatChart(...)

# %%
# Transition matrix
driver.transition_matrix(left_value_functions)
# Out:
# <style type="text/css">
# #T_88faa_row0_col0, #T_88faa_row1_col1, #T_88faa_row2_col2, #T_88faa_row3_col3, #T_88faa_row4_col4, #T_88faa_row5_col5, #T_88faa_row6_col6, #T_88faa_row7_col7, #T_88faa_row8_col8, #T_88faa_row9_col9, #T_88faa_row10_col10, #T_88faa_row11_col11, #T_88faa_row12_col12, #T_88faa_row13_col13, #T_88faa_row14_col14, #T_88faa_row15_col15, #T_88faa_row16_col16, #T_88faa_row17_col17, #T_88faa_row17_col19, #T_88faa_row18_col18, #T_88faa_row18_col20 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# 3) Under a policy that “tries to go left” with 50% probability and “tries to go right” with
# 50% probability:
#
# - Rerun the code and recreate table 2.1, 2.4, and 2.6
# - Recreate figures 2.2 and 2.3
# - Construct the transition probability matrix

# %%
# Table 2.1
driver.run_episode(direction="random")
# Out:
#      t  observation  observation_next  action  reward  beta    beta^t  \
# 0    0            0                -1     1.0   -0.05  0.98  1.000000
# 1    1           -1                -2     0.0   -0.05  0.98  0.980000
# 2    2           -2                -1     1.0   -0.05  0.98  0.960400
# 3    3           -1                -2     0.0   -0.05  0.98  0.941192
# 4    4           -2                -3     1.0   -0.05  0.98  0.922368
# 5    5           -3                -2     1.0   -0.05  0.98  0.903921
# 6    6           -2                -3     0.0   -0.05  0.98  0.885842
# 7    7           -3                -2     0.0   -0.05  0.98  0.868126
# 8    8           -2                -3     0.0   -0.05  0.98  0.850763
# 9    9           -3                -2     1.0   -0.05  0.98  0.833748
# 10  10           -2                -3     0.0   -0.05  0.98  0.817073
# 11  11           -3                -4     0.0   -0.05  0.98  0.800731
# ...

# %%
# Table 2.4
random_episodes = driver.run_episodes(direction="random")
driver.tab_2_4(random_episodes)
# Out:
#        beta^t_reward
# count    1000.000000
# mean       -0.033630
# std         0.015248
# min        -0.108242
# 1%         -0.087009
# 5%         -0.064895
# 10%        -0.050879
# 25%        -0.031792
# 50%        -0.031792
# 75%        -0.031792
# 90%        -0.020679
# 95%        -0.012533
# 99%         0.005312
# max         0.041812

# %%
# Table 2.6
random_value_functions = driver.estimate_v(direction="random")
random_policy_summary = driver.summarize(random_value_functions)
random_policy_summary
# Out:
#     initial_state  count      mean       std       min        1%       5%  \
# 0              -9   1000 -0.115835  0.257837 -1.000000 -1.000000 -0.96040
# 1              -8   1000 -0.069569  0.167199 -0.980000 -0.980000 -0.05000
# 2              -7   1000 -0.054418  0.123665 -0.960400 -0.885842 -0.05000
# 3              -6   1000 -0.047100  0.099160 -0.941192 -0.769022 -0.05000
# 4              -5   1000 -0.041518  0.077281 -0.922368 -0.523883 -0.04900
# 5              -4   1000 -0.038348  0.062939 -0.903921 -0.050000 -0.04900
# 6              -3   1000 -0.037024  0.056480 -0.885842 -0.050000 -0.04900
# 7              -2   1000 -0.034904  0.051292 -0.868126 -0.050000 -0.04900
# 8              -1   1000 -0.033281  0.049422 -0.850763 -0.050000 -0.04802
# 9               0   1000 -0.032609  0.048293 -0.833748 -0.050000 -0.04802
# 10              1   1000 -0.032084  0.049114 -0.817073 -0.050000 -0.04802
# 11              2   1000 -0.030345  0.056283 -0.769022 -0.050000 -0.04802
# ...

# %%
# Figures 2.2 and 2.3
driver.plot_fig_2_2(random_value_functions) | driver.plot_fig_2_3(random_value_functions)
# Out:
# alt.HConcatChart(...)

# %%
# Transition matrix
driver.transition_matrix(random_value_functions)
# Out:
# <style type="text/css">
# #T_e83a6_row0_col0, #T_e83a6_row0_col2, #T_e83a6_row1_col1, #T_e83a6_row2_col4, #T_e83a6_row3_col3, #T_e83a6_row4_col6, #T_e83a6_row5_col5, #T_e83a6_row6_col8, #T_e83a6_row7_col7, #T_e83a6_row7_col9, #T_e83a6_row8_col10, #T_e83a6_row9_col9, #T_e83a6_row11_col11, #T_e83a6_row12_col12, #T_e83a6_row12_col14, #T_e83a6_row13_col13, #T_e83a6_row14_col14, #T_e83a6_row14_col16, #T_e83a6_row15_col15, #T_e83a6_row15_col17, #T_e83a6_row16_col18, #T_e83a6_row17_col17, #T_e83a6_row17_col19, #T_e83a6_row18_col20 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# ...
